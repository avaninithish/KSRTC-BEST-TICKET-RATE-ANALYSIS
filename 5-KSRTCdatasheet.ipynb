# %%
import pandas as pd 
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv("C:\\Users\\LAPTOP\\Downloads\\ticket_08_2017.csv")
df
# Out:
#         sync_ticket_id  sync_tkt_owner_id  sync_tkt_device_id  \
# 0               402854           15050034                  34
# 1               402855           15050034                  34
# 2               402856           15050034                  34
# 3               402894           15050034                  34
# 4               402966           15050034                  34
# ...                ...                ...                 ...
# 217383          641842           15050217                 234
# 217384          641843           15050217                 234
# 217385          641844           15050217                 234
# 217386          641845           15050217                 234
# 217387          641846           15050217                 234
#
#        sync_tkt_employee_id sync_tkt_vehicle_id sync_tkt_route_code  \
# 0                      EMP1        KL-06-D-9858                9858
# 1                      EMP1        KL-06-D-9858                9858
# ...

# %%
df.columns
# Out:
# Index(['sync_ticket_id', 'sync_tkt_owner_id', 'sync_tkt_device_id',
#        'sync_tkt_employee_id', 'sync_tkt_vehicle_id', 'sync_tkt_route_code',
#        'sync_tkt_route_name', 'sync_tkt_schedule_no', 'sync_tkt_trip_no',
#        'sync_tkt_start_stage_name', 'sync_tkt_end_stage_name', 'sync_tkt_uid',
#        'sync_tkt_full_count', 'sync_tkt_half_count', 'sync_tkt_student_count',
#        'sync_tkt_ph_count', 'sync_tkt_pass_count', 'sync_tkt_luggage_count',
#        'sync_tkt_warrant_count', 'sync_tkt_full_amount',
#        'sync_tkt_half_amount', 'sync_tkt_student_amount', 'sync_tkt_ph_amount',
#        'sync_tkt_pass_amount', 'sync_tkt_luggage_amount',
#        'sync_tkt_warrant_amount', 'sync_tkt_updown_trip', 'sync_tkt_ticket_no',
#        'sync_tkt_total_amount', 'sync_tkt_discount_amount',
#        'sync_tkt_card_ticket_status', 'sync_tkt_card_id',
#        'sync_tkt_card_balance_amount', 'sync_tkt_card_prv_balance_amount',
# ...

# %%
# df1=df[['sync_tkt_route_name','sync_tkt_schedule_no','sync_tkt_trip_no',
#       'sync_tkt_start_stage_name','sync_tkt_end_stage_name',
#        'sync_tkt_uid','sync_tkt_full_count']]
# df1

# %%
df1=df.iloc[:,6:13]
df1
# Out:
#        sync_tkt_route_name  sync_tkt_schedule_no  sync_tkt_trip_no  \
# 0             CHRY-NEDKNDM                     1                 2
# 1             CHRY-NEDKNDM                     1                 2
# 2             CHRY-NEDKNDM                     1                 2
# 3             CHRY-NEDKNDM                     1                 2
# 4             CHRY-NEDKNDM                     1                 2
# ...                    ...                   ...               ...
# 217383         KTYM-CHRTLA                     1                 2
# 217384         KTYM-CHRTLA                     1                 2
# 217385         KTYM-CHRTLA                     1                 2
# 217386         KTYM-CHRTLA                     1                 2
# 217387         KTYM-CHRTLA                     1                 2
#
#        sync_tkt_start_stage_name sync_tkt_end_stage_name         sync_tkt_uid  \
# 0                      KATTAPANA               MARUKULAM  2017-07-31 14:43:35
# ...

# %%
df1.columns
# Out:
# Index(['sync_tkt_route_name', 'sync_tkt_schedule_no', 'sync_tkt_trip_no',
#        'sync_tkt_start_stage_name', 'sync_tkt_end_stage_name', 'sync_tkt_uid',
#        'sync_tkt_full_count'],
#       dtype='object')

# %%
df1.groupby(['sync_tkt_route_name', 'sync_tkt_schedule_no', 'sync_tkt_trip_no',
       'sync_tkt_start_stage_name', 'sync_tkt_end_stage_name'],as_index=False).agg({'sync_tkt_full_count':sum})
# Out:
#       sync_tkt_route_name  sync_tkt_schedule_no  sync_tkt_trip_no  \
# 0            ANGLVLY-KTYM                     1                 1
# 1            ANGLVLY-KTYM                     1                 1
# 2            ANGLVLY-KTYM                     1                 1
# 3            ANGLVLY-KTYM                     1                 1
# 4            ANGLVLY-KTYM                     1                 1
# ...                   ...                   ...               ...
# 45745      VAIKOM-PNCHKAD                     3                 5
# 45746      VAIKOM-PNCHKAD                     3                 6
# 45747      VAIKOM-PNCHKAD                     3                 6
# 45748      VAIKOM-PNCHKAD                     3                 7
# 45749      VAIKOM-PNCHKAD                     3                 7
#
#       sync_tkt_start_stage_name sync_tkt_end_stage_name  sync_tkt_full_count
# 0                         8MILE                MANIMALA                   13
# ...

# %%
x=df1.iloc[:,[0,1,2,3,4]].values
y=df1.iloc[:,-1].values
print(x)
print(y)
# Out:
# [['CHRY-NEDKNDM' 1 2 'KATTAPANA' 'MARUKULAM']
#  ['CHRY-NEDKNDM' 1 2 'KATTAPANA' 'PARAPU']
#  ['CHRY-NEDKNDM' 1 2 'KATTAPANA' 'KUTTIKANNAM']
#  ...
#  ['KTYM-CHRTLA' 1 2 'CHERTALA' 'ILLICKAL']
#  ['KTYM-CHRTLA' 1 2 'CHERTALA' 'KOTTAYAM']
#  ['KTYM-CHRTLA' 1 2 'CHERTALA' 'KATACHIRA']]
# [1 1 1 ... 1 1 1]

# %%
labelencoder=LabelEncoder()
x[:,0]=labelencoder.fit_transform(x[:,0])
x[:,3]=labelencoder.fit_transform(x[:,3])
x[:,4]=labelencoder.fit_transform(x[:,4])

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y)
regressor=LinearRegression()
regressor.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=regressor.predict(x_test)
for i,pred in enumerate(y_pred):
    
    print("predictions",pred,"Actual:",y_test[i])
# Out:
# predictions 1.0505276580089344 Actual: 1
# predictions 1.0551964508500586 Actual: 1
# predictions 1.0730622240827106 Actual: 1
# predictions 1.0559931603116326 Actual: 1
# predictions 1.0554895622678024 Actual: 1
# predictions 1.0516790565646785 Actual: 1
# predictions 1.0471993558170434 Actual: 1
# predictions 1.050838682563293 Actual: 1
# predictions 1.0480832276528378 Actual: 1
# predictions 1.0586110587813764 Actual: 1
# predictions 1.0563486254883696 Actual: 1
# predictions 1.050191867472087 Actual: 2
# predictions 1.0529845769334236 Actual: 1
# predictions 1.0543655152685694 Actual: 1
# predictions 1.0524091330938758 Actual: 1
# predictions 1.0499407662128748 Actual: 1
# predictions 1.05278380908668 Actual: 1
# predictions 1.0512411211488037 Actual: 1
# predictions 1.0519839182851964 Actual: 1
# predictions 1.0552405545692185 Actual: 1
# predictions 1.0481162020433574 Actual: 1
# predictions 1.0532824494473427 Actual: 1
# predictions 1.050706629072233 Actual: 1
# ...

# %%
print(regressor.score(x_test,y_test))
# Out:
# 7.813882909191161e-05
